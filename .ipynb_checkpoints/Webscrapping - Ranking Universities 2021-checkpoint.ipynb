# %%
# Import Dependencies
from bs4 import BeautifulSoup
import os
import pandas as pd

# %% [markdown]
# ### Ranking Page

# %%
# Ranking Page
filepath = os.path.join("sources/World University Rankings - Ranking.html")
with open(filepath, encoding='utf-8') as file:
    htmlRanking = file.read()

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soupRanking = BeautifulSoup(htmlRanking, 'html.parser')

# %%
# Retrieve the anchors for all university names
anchorTitles = soupRanking.find_all('a', class_='ranking-institution-title')

# Create empty list
universitiesNames = []

# loop over results to get the data
for title in anchorTitles:
    name = title.text
    universitiesNames.append(name)

# %%
# Retrieve the parent divs for locations
anchorLocations = soupRanking.find_all('div', class_='location')

# Create empty list
universitiesLocations = []

# Loop over results to get the data
for locations in anchorLocations:
    country = locations.find('a').text
    universitiesLocations.append(country)

# %%
# Retrieve the rows for get stats - Number of Students
trRole = soupRanking.find_all('td', class_='stats_number_students')

# Create empty list
numberStudents = []

# Loop over results to get the data
for tr in trRole:
    number = tr.text
    numberStudents.append(number)

# %%
# Retrieve the rows for get stats - Student Staff Ratio
trRole = soupRanking.find_all('td', class_='stats stats_student_staff_ratio')

# Create empty list
studentsStaffRatio = []

# Loop over results to get the data
for tr in trRole:
    ratio = tr.text
    studentsStaffRatio.append(ratio)

# %%
# Retrieve the rows for get stats - % of international students
trRole = soupRanking.find_all('td', class_='stats stats_pc_intl_students')

# Create empty list
percIntStudents = []

# Loop over results to get the data
for tr in trRole:
    perc = tr.text
    percIntStudents.append(perc)

# %%
# Retrieve the rows for get stats - female/male ratio
trRole = soupRanking.find_all('td', class_='stats stats_female_male_ratio')

# Create empty list
genderRatio = []

# Loop over results to get the data
for tr in trRole:
    ratio = tr.text
    genderRatio.append(ratio)

# %%
# Create dictionary
rankingTable = {
    'title' : universitiesNames,
    'location' : universitiesLocations,
    'number students' : numberStudents,
    'students staff ratio' : studentsStaffRatio,
    'perc intl students' : percIntStudents,
    'gender ratio' : genderRatio
}

# %%
# Transform dict to dataframe
ranking_df = pd.DataFrame.from_dict(rankingTable)
ranking_df.set_index(['title', 'location'], inplace=True)
ranking_df
# Out:
#                                                               number students  \
# title                                          location
# University of Oxford                           United Kingdom          20,774
# Stanford University                            United States           16,223
# Harvard University                             United States           21,261
# California Institute of Technology             United States            2,238
# Massachusetts Institute of Technology          United States           11,276
# ...                                                                       ...
# Yuan Ze University                             Taiwan                   8,188
# Yuriy Fedkovych Chernivtsi National University Ukraine                 12,616
# Zagazig University                             Egypt                  156,270
# University of Zagreb                           Croatia                 59,336
# University of Žilina                           Slovakia                 7,136
#
#                                                               students staff ratio  \
# title                                          location
# University of Oxford                           United Kingdom                 11.1
# Stanford University                            United States                   7.4
# Harvard University                             United States                   9.3
# California Institute of Technology             United States                   6.3
# Massachusetts Institute of Technology          United States                   8.4
# ...                                                                            ...
# Yuan Ze University                             Taiwan                         19.7
# Yuriy Fedkovych Chernivtsi National University Ukraine                        10.7
# Zagazig University                             Egypt                          24.4
# University of Zagreb                           Croatia                        15.3
# University of Žilina                           Slovakia                       11.7
#
#                                                               perc intl students  \
# title                                          location
# University of Oxford                           United Kingdom                41%
# Stanford University                            United States                 23%
# Harvard University                             United States                 25%
# California Institute of Technology             United States                 33%
# Massachusetts Institute of Technology          United States                 34%
# ...                                                                          ...
# Yuan Ze University                             Taiwan                         7%
# Yuriy Fedkovych Chernivtsi National University Ukraine                        0%
# Zagazig University                             Egypt                          2%
# University of Zagreb                           Croatia                        3%
# University of Žilina                           Slovakia                       2%
#
#                                                               gender ratio
# title                                          location
# University of Oxford                           United Kingdom      46 : 54
# Stanford University                            United States       44 : 56
# Harvard University                             United States       49 : 51
# California Institute of Technology             United States       36 : 64
# Massachusetts Institute of Technology          United States       39 : 61
# ...                                                                    ...
# Yuan Ze University                             Taiwan              42 : 58
# Yuriy Fedkovych Chernivtsi National University Ukraine             57 : 43
# Zagazig University                             Egypt               54 : 46
# University of Zagreb                           Croatia             59 : 41
# University of Žilina                           Slovakia            34 : 66
#
# [1526 rows x 4 columns]

# %%
ranking_df.to_csv('universities_ranking.csv', header=True, encoding='utf-8-sig')

# %% [markdown]
# ## Scores Page

# %%
# Scores Page
filepath = os.path.join("sources/World University Rankings - Scores.html")
with open(filepath, encoding='utf-8') as file:
    htmlScores = file.read()

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soupScores = BeautifulSoup(htmlScores, 'html.parser')

# %%
# Retrieve the anchors for all university names
anchorTitles = soupScores.find_all('a', class_='ranking-institution-title')

# Create empty list
universitiesNames = []

# loop over results to get the data
for title in anchorTitles:
    name = title.text
    universitiesNames.append(name)

# %%
# Retrieve the parent divs for locations
anchorLocations = soupScores.find_all('div', class_='location')

# Create empty list
universitiesLocations = []

# Loop over results to get the data
for locations in anchorLocations:
    country = locations.find('a').text
    universitiesLocations.append(country)

# %%
# Retrieve the rows for get stats - Overall Score
trRole = soupScores.find_all('td', class_='scores overall-score')

# Create empty list
overallScore = []

# Loop over results to get the data
for tr in trRole:
    score = tr.text
    overallScore.append(score)

# %%
# Retrieve the rows for get stats - Teaching Score
trRole = soupScores.find_all('td', class_='scores teaching-score')

# Create empty list
teachingScore = []

# Loop over results to get the data
for tr in trRole:
    score = tr.text
    teachingScore.append(score)

# %%
# Retrieve the rows for get stats - Research Score
trRole = soupScores.find_all('td', class_='scores research-score')

# Create empty list
researchScore = []

# Loop over results to get the data
for tr in trRole:
    score = tr.text
    researchScore.append(score)

# %%
# Retrieve the rows for get stats - Citations Score
trRole = soupScores.find_all('td', class_='scores citations-score')

# Create empty list
citationsScore = []

# Loop over results to get the data
for tr in trRole:
    score = tr.text
    citationsScore.append(score)

# %%
# Retrieve the rows for get stats - Industry Income Score
trRole = soupScores.find_all('td', class_='scores industry_income-score')

# Create empty list
industryIncomeScore = []

# Loop over results to get the data
for tr in trRole:
    score = tr.text
    industryIncomeScore.append(score)

# %%
# Retrieve the rows for get stats - International Outlook Score
trRole = soupScores.find_all('td', class_='scores international_outlook-score')

# Create empty list
intlOutlookScore = []

# Loop over results to get the data
for tr in trRole:
    score = tr.text
    intlOutlookScore.append(score)

# %%
# Create dictionary
scoreTable = {
    'title' : universitiesNames,
    'location' : universitiesLocations,
    'overall score' : overallScore,
    'teaching score' : teachingScore,
    'research score' : researchScore,
    'citations score' : citationsScore,
    'industry income score' : industryIncomeScore,
    'intl outlook score' : intlOutlookScore
}

# %%
# Transform dict to dataframe
score_df = pd.DataFrame.from_dict(scoreTable)
score_df.set_index(['title', 'location'], inplace=True)
score_df
# Out:
#                                                               overall score  \
# title                                          location
# University of Oxford                           United Kingdom          95.6
# Stanford University                            United States           94.9
# Harvard University                             United States           94.8
# California Institute of Technology             United States           94.5
# Massachusetts Institute of Technology          United States           94.4
# ...                                                                     ...
# Yuan Ze University                             Taiwan             10.3–25.0
# Yuriy Fedkovych Chernivtsi National University Ukraine            10.3–25.0
# Zagazig University                             Egypt              10.3–25.0
# University of Zagreb                           Croatia            10.3–25.0
# University of Žilina                           Slovakia           10.3–25.0
#
#                                                               teaching score  \
# title                                          location
# University of Oxford                           United Kingdom           91.3
# Stanford University                            United States            92.2
# Harvard University                             United States            94.4
# California Institute of Technology             United States            92.5
# Massachusetts Institute of Technology          United States            90.7
# ...                                                                      ...
# Yuan Ze University                             Taiwan                   18.8
# Yuriy Fedkovych Chernivtsi National University Ukraine                  17.9
# Zagazig University                             Egypt                    13.7
# University of Zagreb                           Croatia                  19.5
# University of Žilina                           Slovakia                 20.3
#
#                                                               research score  \
# title                                          location
# University of Oxford                           United Kingdom           99.6
# Stanford University                            United States            96.7
# Harvard University                             United States            98.8
# California Institute of Technology             United States            96.9
# Massachusetts Institute of Technology          United States            94.4
# ...                                                                      ...
# Yuan Ze University                             Taiwan                   14.1
# Yuriy Fedkovych Chernivtsi National University Ukraine                   7.7
# Zagazig University                             Egypt                     7.4
# University of Zagreb                           Croatia                  13.2
# University of Žilina                           Slovakia                 13.2
#
#                                                               citations score  \
# title                                          location
# University of Oxford                           United Kingdom            98.0
# Stanford University                            United States             99.9
# Harvard University                             United States             99.4
# California Institute of Technology             United States             97.0
# Massachusetts Institute of Technology          United States             99.7
# ...                                                                       ...
# Yuan Ze University                             Taiwan                    19.7
# Yuriy Fedkovych Chernivtsi National University Ukraine                    5.3
# Zagazig University                             Egypt                     42.3
# University of Zagreb                           Croatia                   27.2
# University of Žilina                           Slovakia                  26.4
#
#                                                               industry income score  \
# title                                          location
# University of Oxford                           United Kingdom                  68.7
# Stanford University                            United States                   90.1
# Harvard University                             United States                   46.8
# California Institute of Technology             United States                   92.7
# Massachusetts Institute of Technology          United States                   90.4
# ...                                                                             ...
# Yuan Ze University                             Taiwan                          50.1
# Yuriy Fedkovych Chernivtsi National University Ukraine                         33.4
# Zagazig University                             Egypt                           33.4
# University of Zagreb                           Croatia                         40.3
# University of Žilina                           Slovakia                        42.9
#
#                                                               intl outlook score
# title                                          location
# University of Oxford                           United Kingdom               96.4
# Stanford University                            United States                79.5
# Harvard University                             United States                77.7
# California Institute of Technology             United States                83.6
# Massachusetts Institute of Technology          United States                90.0
# ...                                                                          ...
# Yuan Ze University                             Taiwan                       30.9
# Yuriy Fedkovych Chernivtsi National University Ukraine                      22.2
# Zagazig University                             Egypt                        40.6
# University of Zagreb                           Croatia                      34.3
# University of Žilina                           Slovakia                     31.8
#
# [1526 rows x 6 columns]

# %%
score_df.to_csv('universities_scores.csv', header=True, encoding='utf-8-sig')

# %% [markdown]
# ## Merge

# %%
# Concatenate Dataframes
universities_df = pd.concat([ranking_df, score_df], axis=1)
universities_df
# Out:
#                                                               number students  \
# title                                          location
# University of Oxford                           United Kingdom          20,774
# Stanford University                            United States           16,223
# Harvard University                             United States           21,261
# California Institute of Technology             United States            2,238
# Massachusetts Institute of Technology          United States           11,276
# ...                                                                       ...
# Yuan Ze University                             Taiwan                   8,188
# Yuriy Fedkovych Chernivtsi National University Ukraine                 12,616
# Zagazig University                             Egypt                  156,270
# University of Zagreb                           Croatia                 59,336
# University of Žilina                           Slovakia                 7,136
#
#                                                               students staff ratio  \
# title                                          location
# University of Oxford                           United Kingdom                 11.1
# Stanford University                            United States                   7.4
# Harvard University                             United States                   9.3
# California Institute of Technology             United States                   6.3
# Massachusetts Institute of Technology          United States                   8.4
# ...                                                                            ...
# Yuan Ze University                             Taiwan                         19.7
# Yuriy Fedkovych Chernivtsi National University Ukraine                        10.7
# Zagazig University                             Egypt                          24.4
# University of Zagreb                           Croatia                        15.3
# University of Žilina                           Slovakia                       11.7
#
#                                                               perc intl students  \
# title                                          location
# University of Oxford                           United Kingdom                41%
# Stanford University                            United States                 23%
# Harvard University                             United States                 25%
# California Institute of Technology             United States                 33%
# Massachusetts Institute of Technology          United States                 34%
# ...                                                                          ...
# Yuan Ze University                             Taiwan                         7%
# Yuriy Fedkovych Chernivtsi National University Ukraine                        0%
# Zagazig University                             Egypt                          2%
# University of Zagreb                           Croatia                        3%
# University of Žilina                           Slovakia                       2%
#
#                                                               gender ratio  \
# title                                          location
# University of Oxford                           United Kingdom      46 : 54
# Stanford University                            United States       44 : 56
# Harvard University                             United States       49 : 51
# California Institute of Technology             United States       36 : 64
# Massachusetts Institute of Technology          United States       39 : 61
# ...                                                                    ...
# Yuan Ze University                             Taiwan              42 : 58
# Yuriy Fedkovych Chernivtsi National University Ukraine             57 : 43
# Zagazig University                             Egypt               54 : 46
# University of Zagreb                           Croatia             59 : 41
# University of Žilina                           Slovakia            34 : 66
#
#                                                               overall score  \
# title                                          location
# University of Oxford                           United Kingdom          95.6
# Stanford University                            United States           94.9
# Harvard University                             United States           94.8
# California Institute of Technology             United States           94.5
# Massachusetts Institute of Technology          United States           94.4
# ...                                                                     ...
# Yuan Ze University                             Taiwan             10.3–25.0
# Yuriy Fedkovych Chernivtsi National University Ukraine            10.3–25.0
# Zagazig University                             Egypt              10.3–25.0
# University of Zagreb                           Croatia            10.3–25.0
# University of Žilina                           Slovakia           10.3–25.0
#
#                                                               teaching score  \
# title                                          location
# University of Oxford                           United Kingdom           91.3
# Stanford University                            United States            92.2
# Harvard University                             United States            94.4
# California Institute of Technology             United States            92.5
# Massachusetts Institute of Technology          United States            90.7
# ...                                                                      ...
# Yuan Ze University                             Taiwan                   18.8
# Yuriy Fedkovych Chernivtsi National University Ukraine                  17.9
# Zagazig University                             Egypt                    13.7
# University of Zagreb                           Croatia                  19.5
# University of Žilina                           Slovakia                 20.3
#
#                                                               research score  \
# title                                          location
# University of Oxford                           United Kingdom           99.6
# Stanford University                            United States            96.7
# Harvard University                             United States            98.8
# California Institute of Technology             United States            96.9
# Massachusetts Institute of Technology          United States            94.4
# ...                                                                      ...
# Yuan Ze University                             Taiwan                   14.1
# Yuriy Fedkovych Chernivtsi National University Ukraine                   7.7
# Zagazig University                             Egypt                     7.4
# University of Zagreb                           Croatia                  13.2
# University of Žilina                           Slovakia                 13.2
#
#                                                               citations score  \
# title                                          location
# University of Oxford                           United Kingdom            98.0
# Stanford University                            United States             99.9
# Harvard University                             United States             99.4
# California Institute of Technology             United States             97.0
# Massachusetts Institute of Technology          United States             99.7
# ...                                                                       ...
# Yuan Ze University                             Taiwan                    19.7
# Yuriy Fedkovych Chernivtsi National University Ukraine                    5.3
# Zagazig University                             Egypt                     42.3
# University of Zagreb                           Croatia                   27.2
# University of Žilina                           Slovakia                  26.4
#
#                                                               industry income score  \
# title                                          location
# University of Oxford                           United Kingdom                  68.7
# Stanford University                            United States                   90.1
# Harvard University                             United States                   46.8
# California Institute of Technology             United States                   92.7
# Massachusetts Institute of Technology          United States                   90.4
# ...                                                                             ...
# Yuan Ze University                             Taiwan                          50.1
# Yuriy Fedkovych Chernivtsi National University Ukraine                         33.4
# Zagazig University                             Egypt                           33.4
# University of Zagreb                           Croatia                         40.3
# University of Žilina                           Slovakia                        42.9
#
#                                                               intl outlook score
# title                                          location
# University of Oxford                           United Kingdom               96.4
# Stanford University                            United States                79.5
# Harvard University                             United States                77.7
# California Institute of Technology             United States                83.6
# Massachusetts Institute of Technology          United States                90.0
# ...                                                                          ...
# Yuan Ze University                             Taiwan                       30.9
# Yuriy Fedkovych Chernivtsi National University Ukraine                      22.2
# Zagazig University                             Egypt                        40.6
# University of Zagreb                           Croatia                      34.3
# University of Žilina                           Slovakia                     31.8
#
# [1526 rows x 10 columns]

# %%
universities_df.to_csv('universities_rankings_scores.csv', header=True, encoding='utf-8-sig')
